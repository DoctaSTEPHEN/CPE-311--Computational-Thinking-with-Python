# %% [markdown]
# <a href="https://colab.research.google.com/github/DoctaSTEPHEN/CPE-311--Computational-Thinking-with-Python/blob/main/Reviewing_Data_Analysis_Tools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Given the following data structures:
#
#     sales = [100,130,119,92,35]
#     customer_account = ['B100','J101','X102','P103','R104']
#     city = ['BOS','LA','NYC','SF','CHI']

# %% [markdown]
# Create a DataFrame with the data above<br>

# %%
df = pd.DataFrame({'sales':[100,130,119,92,35],
                   'customer_account':['B100','J101','X102','P103','R104'],
                   'city':['BOS','LA','NYC','SF','CHI']})
df
# Out:
#    sales customer_account city
# 0    100             B100  BOS
# 1    130             J101   LA
# 2    119             X102  NYC
# 3     92             P103   SF
# 4     35             R104  CHI

# %% [markdown]
# What is the name of the first column?

# %%
df.columns
# Out:
# Index(['sales', 'customer_account', 'city'], dtype='object')

# %% [markdown]
# Sort the DataFrame by city in descending order (check the documentation for sort)

# %%
df.sort_values('city', inplace = True, ascending = False)

# %%
df
# Out:
#    sales customer_account city
# 3     92             P103   SF
# 2    119             X102  NYC
# 1    130             J101   LA
# 4     35             R104  CHI
# 0    100             B100  BOS

# %% [markdown]
# Which customer is in the last row of the DataFrame?

# %%
df.iloc[-1:]
# Out:
#    sales customer_account city
# 0    100             B100  BOS

# %% [markdown]
# Reorder the columns with customer in the first column

# %%
df.sort_values('customer_account', inplace = True, ascending = True)

# %%
df
# Out:
#    sales customer_account city
# 0    100             B100  BOS
# 1    130             J101   LA
# 3     92             P103   SF
# 4     35             R104  CHI
# 2    119             X102  NYC

# %% [markdown]
# 2. Load the Titanic Dataset and answer the following questions:

# %%
df = pd.read_csv('/Titanic-Dataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# What was the average age of the survivors?

# %%
df.Age[df.Survived==True].mean()
# Out:
# np.float64(28.343689655172415)

# %% [markdown]
# What was the combined survival rate of both children (age less than 18) and seniors (age greater than 60)?

# %%
df.Survived[(df.Age >= 60) | (df.Age <= 18)].mean()
# Out:
# np.float64(0.4666666666666667)

# %% [markdown]
# Group by pClass and investigate average survival rate, age and fare

# %%
df.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
df.groupby('Pclass')['Age'].mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
df.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
#Create a CSV with the names and ages of the survivors and another CSV file with the names and ages of the deceased.
survivors = df[df.Survived==True]
survivors[['Name', 'Age']].to_csv('Survivors.csv')

deceased = df[df.Survived==False]
deceased[['Name', 'Age']].to_csv('deceased.csv')
