# %%
import pandas as pd

# %%
meteorites = pd.read_csv('Meteorite_Landings.csv')
meteorites
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation
# ...

# %%
meteorites['name']
meteorites.name
# Out:
# 0            Aachen
# 1            Aarhus
# 2              Abee
# 3          Acapulco
# 4           Achiras
#             ...
# 45711    Zillah 002
# 45712        Zinder
# 45713          Zlin
# 45714     Zubkovsky
# 45715    Zulu Queen
# Name: name, Length: 45716, dtype: object

# %%
meteorites.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
meteorites.index
# Out:
# RangeIndex(start=0, stop=45716, step=1)

# %%
import requests

response = requests.get('https://data.nasa.gov/resource/gh4g-9sfh.json',
                       params = {'$limit': 50_000})

if response.ok:
    payload = response.json()
else:
    print(f'Request was not successful and returned code: {response.status_code}.')
    payload = None

# %%
payload[:5]
# Out:
# [{'name': 'Aachen',
#   'id': '1',
#   'nametype': 'Valid',
#   'recclass': 'L5',
#   'mass': '21',
#   'fall': 'Fell',
#   'year': '1880-01-01T00:00:00.000',
#   'reclat': '50.775000',
#   'reclong': '6.083330',
#   'geolocation': {'latitude': '50.775', 'longitude': '6.08333'}},
#  {'name': 'Aarhus',
#   'id': '2',
#   'nametype': 'Valid',
#   'recclass': 'H6',
#   'mass': '720',
#   'fall': 'Fell',
#   'year': '1951-01-01T00:00:00.000',
#   'reclat': '56.183330',
#   'reclong': '10.233330',
#   'geolocation': {'latitude': '56.18333', 'longitude': '10.23333'}},
#  {'name': 'Abee',
#   'id': '6',
#   'nametype': 'Valid',
#   'recclass': 'EH4',
#   'mass': '107000',
#   'fall': 'Fell',
#   'year': '1952-01-01T00:00:00.000',
#   'reclat': '54.216670',
#   'reclong': '-113.000000',
#   'geolocation': {'latitude': '54.21667', 'longitude': '-113.0'}},
#  {'name': 'Acapulco',
#   'id': '10',
#   'nametype': 'Valid',
#   'recclass': 'Acapulcoite',
#   'mass': '1914',
#   'fall': 'Fell',
# ...

# %%
df = pd.DataFrame(payload)
df.head(3)
# Out:
#      name id nametype recclass    mass  fall                     year  \
# 0  Aachen  1    Valid       L5      21  Fell  1880-01-01T00:00:00.000
# 1  Aarhus  2    Valid       H6     720  Fell  1951-01-01T00:00:00.000
# 2    Abee  6    Valid      EH4  107000  Fell  1952-01-01T00:00:00.000
#
#       reclat      reclong                                        geolocation  \
# 0  50.775000     6.083330     {'latitude': '50.775', 'longitude': '6.08333'}
# 1  56.183330    10.233330  {'latitude': '56.18333', 'longitude': '10.23333'}
# 2  54.216670  -113.000000    {'latitude': '54.21667', 'longitude': '-113.0'}
#
#   :@computed_region_cbhk_fwbd :@computed_region_nnqa_25f4
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN

# %%
meteorites
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation
# ...

# %%
meteorites.shape #attribute of meteorites
# Out:
# (45716, 10)

# %%
meteorites.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
meteorites.dtypes #attribute of meteorites
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass (g)       float64
# fall            object
# year            object
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %%
meteorites.head(10)
# Out:
#                   name   id nametype     recclass  mass (g)  fall  \
# 0               Aachen    1    Valid           L5      21.0  Fell
# 1               Aarhus    2    Valid           H6     720.0  Fell
# 2                 Abee    6    Valid          EH4  107000.0  Fell
# 3             Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4              Achiras  370    Valid           L6     780.0  Fell
# 5             Adhi Kot  379    Valid          EH4    4239.0  Fell
# 6  Adzhi-Bogdo (stone)  390    Valid        LL3-6     910.0  Fell
# 7                 Agen  392    Valid           H5   30000.0  Fell
# 8               Aguada  398    Valid           L6    1620.0  Fell
# 9        Aguila Blanca  417    Valid            L    1440.0  Fell
#
#                      year    reclat    reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# ...

# %%
meteorites.tail()
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation
# 45711  01/01/1990 12:00:00 AM  29.03700   17.01850       (29.037, 17.0185)
# 45712  01/01/1999 12:00:00 AM  13.78333    8.96667     (13.78333, 8.96667)
# 45713  01/01/1939 12:00:00 AM  49.25000   17.66667       (49.25, 17.66667)
# 45714  01/01/2003 12:00:00 AM  49.78917   41.50460     (49.78917, 41.5046)
# 45715  01/01/1976 12:00:00 AM  33.98333 -115.68333  (33.98333, -115.68333)

# %%
meteorites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         45716 non-null  object
#  1   id           45716 non-null  int64
#  2   nametype     45716 non-null  object
#  3   recclass     45716 non-null  object
#  4   mass (g)     45585 non-null  float64
#  5   fall         45716 non-null  object
#  6   year         45425 non-null  object
#  7   reclat       38401 non-null  float64
#  8   reclong      38401 non-null  float64
#  9   GeoLocation  38401 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.5+ MB

# %%
meteorites[['name','recclass']]
# Out:
#              name              recclass
# 0          Aachen                    L5
# 1          Aarhus                    H6
# 2            Abee                   EH4
# 3        Acapulco           Acapulcoite
# 4         Achiras                    L6
# ...           ...                   ...
# 45711  Zillah 002               Eucrite
# 45712      Zinder  Pallasite, ungrouped
# 45713        Zlin                    H4
# 45714   Zubkovsky                    L6
# 45715  Zulu Queen                  L3.7
#
# [45716 rows x 2 columns]

# %%
meteorites.iloc[100:104, [0,3,4,6]]
# Out:
#               name       recclass  mass (g)                    year
# 100         Benton            LL6    2840.0  01/01/1949 12:00:00 AM
# 101         Berduc             L6     270.0  01/01/2008 12:00:00 AM
# 102         Béréba  Eucrite-mmict   18000.0  01/01/1924 12:00:00 AM
# 103  Berlanguillas             L6    1440.0  01/01/1811 12:00:00 AM

# %%
meteorites.loc[100:104,'mass (g)':'year']
# Out:
#      mass (g)  fall                    year
# 100    2840.0  Fell  01/01/1949 12:00:00 AM
# 101     270.0  Fell  01/01/2008 12:00:00 AM
# 102   18000.0  Fell  01/01/1924 12:00:00 AM
# 103    1440.0  Fell  01/01/1811 12:00:00 AM
# 104     960.0  Fell  01/01/2004 12:00:00 AM

# %%
meteorites.iloc[-1, -1]
# Out:
# '(33.98333, -115.68333)'

# %%
(meteorites['mass (g)']>50) & (meteorites.fall=='Found')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45711     True
# 45712    False
# 45713    False
# 45714     True
# 45715     True
# Length: 45716, dtype: bool

# %%
meteorites[(meteorites['mass (g)']>50) & (meteorites.fall=='Found')]
# Out:
#                         name     id nametype recclass   mass (g)   fall  \
# 37     Northwest Africa 5815  50693    Valid       L5     256.80  Found
# 757     Dominion Range 03239  32591    Valid       L6      69.50  Found
# 804     Dominion Range 03240  32592    Valid      LL5     290.90  Found
# 1111                   Abajo      4    Valid       H5     331.00  Found
# 1112         Abar al' Uj 001  51399    Valid     H3.8     194.34  Found
# ...                      ...    ...      ...      ...        ...    ...
# 45709             Zhongxiang  30406    Valid     Iron  100000.00  Found
# 45710             Zillah 001  31355    Valid       L6    1475.00  Found
# 45711             Zillah 002  31356    Valid  Eucrite     172.00  Found
# 45714              Zubkovsky  31357    Valid       L6    2167.00  Found
# 45715             Zulu Queen  30414    Valid     L3.7     200.00  Found
#
#                          year    reclat    reclong             GeoLocation
# ...

# %%
meteorites.query("`mass (g)` > 1e6 and fall=='Fell'")
# Out:
#               name     id nametype    recclass    mass (g)  fall  \
# 29         Allende   2278    Valid         CV3   2000000.0  Fell
# 419          Jilin  12171    Valid          H5   4000000.0  Fell
# 506  Kunya-Urgench  12379    Valid          H5   1100000.0  Fell
# 707  Norton County  17922    Valid     Aubrite   1100000.0  Fell
# 920   Sikhote-Alin  23593    Valid  Iron, IIAB  23000000.0  Fell
#
#                        year    reclat    reclong             GeoLocation
# 29   01/01/1969 12:00:00 AM  26.96667 -105.31667  (26.96667, -105.31667)
# 419  01/01/1976 12:00:00 AM  44.05000  126.16667      (44.05, 126.16667)
# 506  01/01/1998 12:00:00 AM  42.25000   59.20000           (42.25, 59.2)
# 707  01/01/1948 12:00:00 AM  39.68333  -99.86667   (39.68333, -99.86667)
# 920  01/01/1947 12:00:00 AM  46.16000  134.65333      (46.16, 134.65333)

# %%
meteorites.fall.value_counts()
# Out:
# fall
# Found    44609
# Fell      1107
# Name: count, dtype: int64

# %%
meteorites.value_counts(subset = ['nametype', 'fall'], normalize = False)#false return raw value
# Out:
# nametype  fall
# Valid     Found    44534
#           Fell      1107
# Relict    Found       75
# Name: count, dtype: int64

# %%
meteorites['mass (g)'].quantile([0.01, 0.05, 0.5, 0.95, 0.99])
# Out:
# 0.01        0.44
# 0.05        1.10
# 0.50       32.60
# 0.95     4000.00
# 0.99    50600.00
# Name: mass (g), dtype: float64

# %%
type(meteorites['mass (g)'].mean())
# Out:
# numpy.float64

# %%
meteorites['mass (g)'].median()
# Out:
# 32.6

# %%
meteorites['mass (g)'].max()
# Out:
# 60000000.0

# %%
meteorites.loc[meteorites['mass (g)'].idxmax()]
# Out:
# name                             Hoba
# id                              11890
# nametype                        Valid
# recclass                    Iron, IVB
# mass (g)                   60000000.0
# fall                            Found
# year           01/01/1920 12:00:00 AM
# reclat                      -19.58333
# reclong                      17.91667
# GeoLocation     (-19.58333, 17.91667)
# Name: 16392, dtype: object

# %%
meteorites.recclass.nunique()
# Out:
# 466

# %%
meteorites.name.nunique()
# Out:
# 45716

# %%
meteorites.recclass.unique()[:4]
# Out:
# array(['L5', 'H6', 'EH4', 'Acapulcoite'], dtype=object)

# %%
meteorites.describe()
# Out:
#                  id      mass (g)        reclat       reclong
# count  45716.000000  4.558500e+04  38401.000000  38401.000000
# mean   26889.735104  1.327808e+04    -39.122580     61.074319
# std    16860.683030  5.749889e+05     46.378511     80.647298
# min        1.000000  0.000000e+00    -87.366670   -165.433330
# 25%    12688.750000  7.200000e+00    -76.714240      0.000000
# 50%    24261.500000  3.260000e+01    -71.500000     35.666670
# 75%    40656.750000  2.026000e+02      0.000000    157.166670
# max    57458.000000  6.000000e+07     81.166670    354.473330

# %%
meteorites.describe(include = 'all')
# Out:
#           name            id nametype recclass      mass (g)   fall  \
# count    45716  45716.000000    45716    45716  4.558500e+04  45716
# unique   45716           NaN        2      466           NaN      2
# top     Aachen           NaN    Valid       L6           NaN  Found
# freq         1           NaN    45641     8285           NaN  44609
# mean       NaN  26889.735104      NaN      NaN  1.327808e+04    NaN
# std        NaN  16860.683030      NaN      NaN  5.749889e+05    NaN
# min        NaN      1.000000      NaN      NaN  0.000000e+00    NaN
# 25%        NaN  12688.750000      NaN      NaN  7.200000e+00    NaN
# 50%        NaN  24261.500000      NaN      NaN  3.260000e+01    NaN
# 75%        NaN  40656.750000      NaN      NaN  2.026000e+02    NaN
# max        NaN  57458.000000      NaN      NaN  6.000000e+07    NaN
#
#                           year        reclat       reclong GeoLocation
# count                    45425  38401.000000  38401.000000       38401
# ...

# %% [markdown]
# Exercise (Part 1)
#
# Using the 2019_Yellow_Taxi_Trip_Data.csv dataset, accomplish the following items and submit a PDF of the notebook:e).

# %% [markdown]
# 1. Create a DataFrame by reading in the 2019_Yellow_Taxi_Trip_Data.csv file. Examine the first 5 rows.

# %%
taxi = pd.read_csv('2019_Yellow_Taxi_Trip_Data.csv')
taxi.head()
# Out:
#    vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0         2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1         1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2         2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3         2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4         2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
#
#    passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0                1           7.93           1                  N
# 1                1           2.00           1                  N
# 2                1           1.36           1                  N
# 3                1           1.00           1                  N
# 4                1           1.96           1                  N
#
#    pulocationid  dolocationid  payment_type  fare_amount  extra  mta_tax  \
# 0           138           170             1         29.5    1.0      0.5
# ...

# %% [markdown]
# 2. Find the dimensions (number of rows and number of columns) in the data.

# %%
rows, columns = taxi.shape
print(f'Rows: {rows}')
print(f'Columns: {columns}')
# Out:
# Rows: 10000
# Columns: 18

# %% [markdown]
# 3. Using the data in the 2019_Yellow_Taxi_Trip_Data.csv file, calculate summary statistics for the fare_amount, tip_amount, tolls_amount, and total_amount columns.

# %%
taxi.describe()[['fare_amount', 'tip_amount', 'tolls_amount', 'total_amount']]
# Out:
#         fare_amount    tip_amount  tolls_amount  total_amount
# count  10000.000000  10000.000000  10000.000000  10000.000000
# mean      15.106313      2.634494      0.623447     22.564659
# std       13.954762      3.409800      6.437507     19.209255
# min      -52.000000      0.000000     -6.120000    -65.920000
# 25%        7.000000      0.000000      0.000000     12.375000
# 50%       10.000000      2.000000      0.000000     16.300000
# 75%       16.000000      3.250000      0.000000     22.880000
# max      176.000000     43.000000    612.000000    671.800000

# %% [markdown]
# 4. Isolate the fare_amount, tip_amount, tolls_amount, and total_amount for the longest trip by distance (trip_distance).

# %%
taxi.iloc[taxi['trip_distance'].idxmax()][['fare_amount', 'tip_amount', 'tolls_amount', 'total_amount']]
# Out:
# fare_amount      176.0
# tip_amount       18.29
# tolls_amount      6.12
# total_amount    201.21
# Name: 8338, dtype: object

# %% [markdown]
# Reflection:
# In this acitivity I was able to learn something new about python pandas, such as describe, shape, max, median, info, and using boolean in pandas. I wasn't able to explore those python pandas function before in our EDA because I was more focused on what would be useful in implementing, and for the completion of our activities and projects.

# %% [markdown]
# Data Wrangling

# %%
taxis = pd.read_csv('2019_Yellow_Taxi_Trip_Data.csv')
taxis
# Out:
#       vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0            2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1            1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2            2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3            2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4            2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
# ...        ...                      ...                      ...
# 9995         1  2019-10-23T17:39:59.000  2019-10-23T17:49:26.000
# 9996         1  2019-10-23T17:53:02.000  2019-10-23T18:00:45.000
# 9997         1  2019-10-23T17:07:16.000  2019-10-23T17:11:35.000
# 9998         1  2019-10-23T17:38:26.000  2019-10-23T17:49:28.000
# 9999         1  2019-10-23T17:22:14.000  2019-10-23T17:52:09.000
#
#       passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0                   1           7.93           1                  N
# ...

# %%
mask = taxis.columns.str.contains('id$|store_and_flag', regex=True)
columns_to_drop = taxis.columns[mask]
columns_to_drop
# Out:
# Index(['vendorid', 'ratecodeid', 'pulocationid', 'dolocationid'], dtype='object')

# %%
taxis.drop(columns='extra').head()
# Out:
#    vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0         2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1         1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2         2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3         2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4         2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
#
#    passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0                1           7.93           1                  N
# 1                1           2.00           1                  N
# 2                1           1.36           1                  N
# 3                1           1.00           1                  N
# 4                1           1.96           1                  N
#
#    pulocationid  dolocationid  payment_type  fare_amount  mta_tax  tip_amount  \
# 0           138           170             1         29.5      0.5        7.98
# ...

# %%
taxis = taxis.rename(columns={
    'tpep_pickup_datetime':'pickup',
    'tpep_dropoff_datetime': 'dropoff'})
taxis
# Out:
#       vendorid                   pickup                  dropoff  \
# 0            2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1            1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2            2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3            2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4            2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
# ...        ...                      ...                      ...
# 9995         1  2019-10-23T17:39:59.000  2019-10-23T17:49:26.000
# 9996         1  2019-10-23T17:53:02.000  2019-10-23T18:00:45.000
# 9997         1  2019-10-23T17:07:16.000  2019-10-23T17:11:35.000
# 9998         1  2019-10-23T17:38:26.000  2019-10-23T17:49:28.000
# 9999         1  2019-10-23T17:22:14.000  2019-10-23T17:52:09.000
#
#       passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0                   1           7.93           1                  N
# ...

# %%
taxis.dtypes
# Out:
# vendorid                   int64
# pickup                    object
# dropoff                   object
# passenger_count            int64
# trip_distance            float64
# ratecodeid                 int64
# store_and_fwd_flag        object
# pulocationid               int64
# dolocationid               int64
# payment_type               int64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# congestion_surcharge     float64
# dtype: object

# %%
taxis[['pickup', 'dropoff']] = taxis[['pickup', 'dropoff']].apply(pd.to_datetime)
taxis.dtypes
# Out:
# vendorid                          int64
# pickup                   datetime64[ns]
# dropoff                  datetime64[ns]
# passenger_count                   int64
# trip_distance                   float64
# ratecodeid                        int64
# store_and_fwd_flag               object
# pulocationid                      int64
# dolocationid                      int64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# dtype: object

# %%
taxis = taxis.assign(
    ellapsed_time = lambda x:x.dropoff - x.pickup,
    cost_before_tip = lambda x:x.total_amount - x.tip_amount,
    tip_pct = lambda x:x.tip_amount / x.cost_before_tip,
    fees = lambda x:x.trip_distance.div(
        x.ellapsed_time.dt.total_seconds()/60/60
    ))
taxis.dtypes
# Out:
# vendorid                           int64
# pickup                    datetime64[ns]
# dropoff                   datetime64[ns]
# passenger_count                    int64
# trip_distance                    float64
# ratecodeid                         int64
# store_and_fwd_flag                object
# pulocationid                       int64
# dolocationid                       int64
# payment_type                       int64
# fare_amount                      float64
# extra                            float64
# mta_tax                          float64
# tip_amount                       float64
# tolls_amount                     float64
# improvement_surcharge            float64
# total_amount                     float64
# congestion_surcharge             float64
# ellapsed_time            timedelta64[ns]
# cost_before_tip                  float64
# tip_pct                          float64
# fees                             float64
# dtype: object

# %%
taxis.sort_values(['ellapsed_time', 'fare_amount'], ascending=[False, True]).head()
# Out:
#       vendorid              pickup             dropoff  passenger_count  \
# 7576         2 2019-10-23 16:52:51 2019-10-24 16:51:44                1
# 6902         2 2019-10-23 16:51:42 2019-10-24 16:50:22                1
# 4975         2 2019-10-23 16:18:51 2019-10-24 16:17:30                1
# 6550         2 2019-10-23 16:49:36 2019-10-24 16:47:40                1
# 2585         2 2019-10-23 16:13:09 2019-10-24 16:11:08                1
#
#       trip_distance  ratecodeid store_and_fwd_flag  pulocationid  \
# 7576           3.75           1                  N           162
# 6902          11.19           1                  N           132
# 4975           0.70           1                  N           161
# 6550           2.54           1                  N           143
# 2585           3.67           1                  N           100
#
#       dolocationid  payment_type  ...  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
taxis = taxis.sort_values(['ellapsed_time', 'fare_amount'], ascending=[False, True])

# %%
taxis.nlargest(3,'total_amount') #nlargest & nsmallest
# Out:
#       vendorid              pickup             dropoff  passenger_count  \
# 449          1 2019-10-23 16:43:02 2019-10-23 18:02:40                1
# 8338         2 2019-10-23 16:50:53 2019-10-24 15:32:55                1
# 853          2 2019-10-23 16:07:39 2019-10-23 17:37:05                3
#
#       trip_distance  ratecodeid store_and_fwd_flag  pulocationid  \
# 449           17.00           2                  N           234
# 8338          38.11           5                  N           132
# 853           19.09           5                  N            10
#
#       dolocationid  payment_type  ...  mta_tax  tip_amount  tolls_amount  \
# 449            132             3  ...      0.5        0.00        612.00
# 8338           265             1  ...      0.5       18.29          6.12
# 853            265             2  ...      0.0        0.00         18.62
#
#       improvement_surcharge  total_amount  congestion_surcharge  \
# ...

# %% [markdown]
# Exercise (Part 2)
# Read in the meteorite data from the Meteorite_Landings.csv file, rename the mass(g) column to mass, and drop all latitude and longtitude columns.Sort the result by mass in descending order.

# %%
meteorite = pd.read_csv('Meteorite_Landings.csv')
meteorite.rename(columns = {'mass (g)':'mass'}, inplace = True)#Rename mass (g) to mass.
meteorite
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation
# ...

# %%
meteorite.drop(columns = ['reclat', 'reclong'], inplace = True) # Drop all latitude and longtitude columns.
meteorite
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year             GeoLocation
# ...

# %%
meteorite.sort_values(['mass'], ascending = False, inplace = True) #Sort the result by mass in descending order.
meteorite
# Out:
#                   name     id nametype      recclass        mass   fall  \
# 16392             Hoba  11890    Valid     Iron, IVB  60000000.0  Found
# 5373         Cape York   5262    Valid   Iron, IIIAB  58200000.0  Found
# 5365   Campo del Cielo   5247    Valid  Iron, IAB-MG  50000000.0  Found
# 5370     Canyon Diablo   5257    Valid  Iron, IAB-MG  30000000.0  Found
# 3455           Armanty   2335    Valid    Iron, IIIE  28000000.0  Found
# ...                ...    ...      ...           ...         ...    ...
# 38282   Wei-hui-fu (a)  24231    Valid          Iron         NaN  Found
# 38283   Wei-hui-fu (b)  24232    Valid          Iron         NaN  Found
# 38285          Weiyuan  24233    Valid  Mesosiderite         NaN  Found
# 41472    Yamato 792768  28117    Valid           CM2         NaN  Found
# 45698    Zapata County  30393    Valid          Iron         NaN  Found
#
#                          year             GeoLocation
# ...

# %%
taxis = taxis.set_index('pickup') #Setting and sorting index
taxis.head(3)
# Out:
#                      vendorid             dropoff  passenger_count  \
# pickup
# 2019-10-23 16:52:51         2 2019-10-24 16:51:44                1
# 2019-10-23 16:51:42         2 2019-10-24 16:50:22                1
# 2019-10-23 16:18:51         2 2019-10-24 16:17:30                1
#
#                      trip_distance  ratecodeid store_and_fwd_flag  \
# pickup
# 2019-10-23 16:52:51           3.75           1                  N
# 2019-10-23 16:51:42          11.19           1                  N
# 2019-10-23 16:18:51           0.70           1                  N
#
#                      pulocationid  dolocationid  payment_type  fare_amount  \
# pickup
# 2019-10-23 16:52:51           162            41             1         17.5
# 2019-10-23 16:51:42           132            62             2         39.5
# 2019-10-23 16:18:51           161           237             2          7.0
#
#                      ...  mta_tax  tip_amount  tolls_amount  \
# pickup               ...
# ...

# %%
taxis = taxis.sort_index() # .sort_index(axis=1)
taxis.sort_index(axis=1).head()
# Out:
#                      congestion_surcharge  cost_before_tip  dolocationid  \
# pickup
# 2019-10-23 07:05:34                   0.0             51.8           181
# 2019-10-23 07:48:58                   2.5              8.8           141
# 2019-10-23 08:02:09                   2.5             36.3            33
# 2019-10-23 08:18:47                   2.5             16.8           237
# 2019-10-23 09:27:16                   0.0              7.8            41
#
#                                 dropoff   ellapsed_time  extra  fare_amount  \
# pickup
# 2019-10-23 07:05:34 2019-10-23 08:03:16 0 days 00:57:42    1.0         50.0
# 2019-10-23 07:48:58 2019-10-23 07:52:09 0 days 00:03:11    1.0          4.5
# 2019-10-23 08:02:09 2019-10-24 07:42:32 0 days 23:40:23    1.0         32.0
# 2019-10-23 08:18:47 2019-10-23 08:36:05 0 days 00:17:18    1.0         12.5
# 2019-10-23 09:27:16 2019-10-23 09:33:13 0 days 00:05:57    1.0          6.0
#
# ...

# %%
taxis.sort_index(axis=0).head()
# Out:
#                      vendorid             dropoff  passenger_count  \
# pickup
# 2019-10-23 07:05:34         2 2019-10-23 08:03:16                3
# 2019-10-23 07:48:58         2 2019-10-23 07:52:09                1
# 2019-10-23 08:02:09         2 2019-10-24 07:42:32                1
# 2019-10-23 08:18:47         2 2019-10-23 08:36:05                1
# 2019-10-23 09:27:16         2 2019-10-23 09:33:13                2
#
#                      trip_distance  ratecodeid store_and_fwd_flag  \
# pickup
# 2019-10-23 07:05:34          14.68           1                  N
# 2019-10-23 07:48:58           0.67           1                  N
# 2019-10-23 08:02:09           8.38           1                  N
# 2019-10-23 08:18:47           2.39           1                  N
# 2019-10-23 09:27:16           1.11           1                  N
#
#                      pulocationid  dolocationid  payment_type  fare_amount  \
# pickup
# ...

# %%
taxis['2019-10-23 07:45':'2019-10-23 08']
# Out:
#                      vendorid             dropoff  passenger_count  \
# pickup
# 2019-10-23 07:48:58         2 2019-10-23 07:52:09                1
# 2019-10-23 08:02:09         2 2019-10-24 07:42:32                1
# 2019-10-23 08:18:47         2 2019-10-23 08:36:05                1
#
#                      trip_distance  ratecodeid store_and_fwd_flag  \
# pickup
# 2019-10-23 07:48:58           0.67           1                  N
# 2019-10-23 08:02:09           8.38           1                  N
# 2019-10-23 08:18:47           2.39           1                  N
#
#                      pulocationid  dolocationid  payment_type  fare_amount  \
# pickup
# 2019-10-23 07:48:58           263           141             2          4.5
# 2019-10-23 08:02:09           237            33             1         32.0
# 2019-10-23 08:18:47           164           237             2         12.5
#
#                      ...  mta_tax  tip_amount  tolls_amount  \
# pickup               ...
# ...

# %%
taxis['2019-10-23':'2019-10-23']
# Out:
#                      vendorid             dropoff  passenger_count  \
# pickup
# 2019-10-23 07:05:34         2 2019-10-23 08:03:16                3
# 2019-10-23 07:48:58         2 2019-10-23 07:52:09                1
# 2019-10-23 08:02:09         2 2019-10-24 07:42:32                1
# 2019-10-23 08:18:47         2 2019-10-23 08:36:05                1
# 2019-10-23 09:27:16         2 2019-10-23 09:33:13                2
# ...                       ...                 ...              ...
# 2019-10-23 17:59:53         2 2019-10-23 18:19:12                1
# 2019-10-23 17:59:53         1 2019-10-23 18:12:56                2
# 2019-10-23 18:00:03         2 2019-10-23 18:04:56                1
# 2019-10-23 18:01:21         2 2019-10-23 18:08:00                5
# 2019-10-23 18:03:03         2 2019-10-23 18:10:45                1
#
#                      trip_distance  ratecodeid store_and_fwd_flag  \
# pickup
# 2019-10-23 07:05:34          14.68           1                  N
# ...

# %%
taxis.loc['2019-10-23 08']
# Out:
#                      vendorid             dropoff  passenger_count  \
# pickup
# 2019-10-23 08:02:09         2 2019-10-24 07:42:32                1
# 2019-10-23 08:18:47         2 2019-10-23 08:36:05                1
#
#                      trip_distance  ratecodeid store_and_fwd_flag  \
# pickup
# 2019-10-23 08:02:09           8.38           1                  N
# 2019-10-23 08:18:47           2.39           1                  N
#
#                      pulocationid  dolocationid  payment_type  fare_amount  \
# pickup
# 2019-10-23 08:02:09           237            33             1         32.0
# 2019-10-23 08:18:47           164           237             2         12.5
#
#                      ...  mta_tax  tip_amount  tolls_amount  \
# pickup               ...
# 2019-10-23 08:02:09  ...      0.5         5.5           0.0
# 2019-10-23 08:18:47  ...      0.5         0.0           0.0
#
#                      improvement_surcharge  total_amount  \
# pickup
# ...

# %%
taxis = taxis.reset_index()
taxis.head()
# Out:
#                pickup  vendorid             dropoff  passenger_count  \
# 0 2019-10-23 07:05:34         2 2019-10-23 08:03:16                3
# 1 2019-10-23 07:48:58         2 2019-10-23 07:52:09                1
# 2 2019-10-23 08:02:09         2 2019-10-24 07:42:32                1
# 3 2019-10-23 08:18:47         2 2019-10-23 08:36:05                1
# 4 2019-10-23 09:27:16         2 2019-10-23 09:33:13                2
#
#    trip_distance  ratecodeid store_and_fwd_flag  pulocationid  dolocationid  \
# 0          14.68           1                  N           132           181
# 1           0.67           1                  N           263           141
# 2           8.38           1                  N           237            33
# 3           2.39           1                  N           164           237
# 4           1.11           1                  N           151            41
#
#    payment_type  ...  mta_tax  tip_amount  tolls_amount  \
# ...

# %% [markdown]
# Exercise (Part 3)

# %%
meteorite = pd.read_csv('Meteorite_Landings.csv')
meteorite.head()
# Out:
#        name   id nametype     recclass  mass (g)  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                      year    reclat    reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000    (54.21667, -113.0)
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000     (16.88333, -99.9)
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000   (-33.16667, -64.95)

# %%
meteorite['year'] = meteorite['year'].fillna(0)

# %%
meteorites = lambda x: x.str[6:10]#convert the "year" column to string and get the year through indexing
meteorite.year = meteorites(meteorite.year) #Use lamda, meteorites, to assign "year" column to only years
meteorite
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#        year    reclat    reclong             GeoLocation
# ...

# %%
meteorite.year = (pd.to_numeric(meteorite['year'])) #Conver it to numeric type
meteorite
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong             GeoLocation
# ...

# %%
meteorite['before 1970'] = (meteorite['year']<1970)
meteorite
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong             GeoLocation  before 1970
# ...

# %%
meteorite = meteorite.set_index('id')
meteorite.sort_index()
# Out:
#                         name nametype recclass  mass (g)   fall    year  \
# id
# 1                     Aachen    Valid       L5      21.0   Fell  1880.0
# 2                     Aarhus    Valid       H6     720.0   Fell  1951.0
# 4                      Abajo    Valid       H5     331.0  Found  1982.0
# 5                     Abbott    Valid     H3-6   21100.0  Found  1951.0
# 6                       Abee    Valid      EH4  107000.0   Fell  1952.0
# ...                      ...      ...      ...       ...    ...     ...
# 57454        Mandalay Spring    Valid       L6    2854.0  Found  2012.0
# 57455               Antelope    Valid       H4     754.0  Found  2012.0
# 57456  Northwest Africa 7870    Valid       L4      42.0  Found  2004.0
# 57457  Northwest Africa 7871    Valid       L6     450.0  Found  2004.0
# 57458  Northwest Africa 7873    Valid     H5-6     446.0  Found  2009.0
#
#          reclat    reclong             GeoLocation  before 1970
# id
# ...

# %%
meteorite[10036:10040]
# Out:
#                         name nametype    recclass  mass (g)   fall    year  \
# id
# 8432  Elephant Moraine 90022    Valid         CK5      15.5  Found  1990.0
# 8433  Elephant Moraine 90023    Valid         CK5      31.5  Found  1990.0
# 8434  Elephant Moraine 90024    Valid  Eucrite-br      22.8  Found  1990.0
# 8435  Elephant Moraine 90025    Valid         CK5      45.8  Found  1990.0
#
#         reclat    reclong             GeoLocation  before 1970
# id
# 8432 -76.28573  156.45721  (-76.28573, 156.45721)        False
# 8433 -76.27507  156.41038  (-76.27507, 156.41038)        False
# 8434 -76.28843  156.47872  (-76.28843, 156.47872)        False
# 8435 -76.28200  156.39926    (-76.282, 156.39926)        False

# %% [markdown]
# <h3>Exercise 4

# %% [markdown]
# 1. Using the meteorite data from the Meteorite_Landings.csv file, create a pivot table that shows both the number of meteorites and the 95th percentile of meteorite mass for those that were found versus observed falling per year from 2005 through 2009 (inclusive). Hint: Be sure to convert the year column to a number as we did in the previous exercise.

# %%
meteorite = pd.read_csv('Meteorite_Landings.csv')
meteorite = meteorite.fillna(0)
meteorite = meteorite.rename(columns={'mass (g)': 'mass'}) #rename column mass(g) to mass for easier access/use
meteorites = lambda x: x.str[6:10]#convert the "year" column to string and get the year through indexing
meteorite.year = meteorites(meteorite.year) #Use lamda, meteorites, to assign "year" column to only years
meteorite.year = (pd.to_numeric(meteorite['year']))#change data type of year column to numeric/float
fall = meteorite[(meteorite['year']>=2005) & (meteorite['year']<=2009)]#filter datas from year 2005-2009

df = {'fall':['found', 'fell'], 
                 'count':[fall.fall[(fall['fall']=='Fell')].count(), fall.fall[(fall['fall']=='Found')].count()], 
                 '95%':[fall.mass[fall['fall']=='Fell'].quantile(.95), fall.mass[fall['fall']=='Found'].quantile(.95)]}
found_vs_fell = pd.DataFrame(df)
found_vs_fell
# Out:
#     fall  count        95%
# 0  found     27  100000.00
# 1   fell   6947    1839.96

# %%
found_vs_fell_pivoted = found_vs_fell.pivot(index = 'fall', columns = 'count', values = '95%')
found_vs_fell_pivoted
# Out:
# count      27       6947
# fall
# fell        NaN  1839.96
# found  100000.0      NaN

# %% [markdown]
# 2. Using the meteorite data from the Meteorite_Landings.csv file, compare summary statistics of the mass column for the meteorites that were found versus observed falling.

# %%
Fell = meteorite[(meteorite.fall == 'Fell')].describe().mass
Found = meteorite[(meteorite.fall == 'Found')].describe().mass
compare = pd.concat([Fell, Found],keys = ['Fell','Found'], axis = 1)
compare
# Out:
#                Fell         Found
# count  1.107000e+03  4.460900e+04
# mean   4.571004e+04  1.243427e+04
# std    7.066615e+05  5.704720e+05
# min    0.000000e+00  0.000000e+00
# 25%    5.970000e+02  6.900000e+00
# 50%    2.500000e+03  3.022200e+01
# 75%    1.000000e+04  1.770000e+02
# max    2.300000e+07  6.000000e+07

# %% [markdown]
# <h3>Exercise 5

# %% [markdown]
# 1. Using the taxi trip data in the 2019_Yellow_Taxi_Trip_Data.csv file, resample the data to an hourly frequency based on the dropoff time. Calculate the total trip_distance, fare_amount, tolls_amount, and tip_amount, then find the 5 hours with the most tips.

# %%
taxis = pd.read_csv('2019_Yellow_Taxi_Trip_Data.csv')
distance = taxis.trip_distance.sum()
fare = taxis.fare_amount.sum()
tolls = taxis.tolls_amount.sum()
tip = taxis.tip_amount.sum()
val = {'Total': [distance, fare, tolls, tip]}
df = pd.DataFrame(val, index = ['trip_distance', 'fare_amount', 'tolls_amount', 'tip_amount'])
df
# Out:
#                    Total
# trip_distance   30152.50
# fare_amount    151063.13
# tolls_amount     6234.47
# tip_amount      26344.94

# %%
taxis[['tpep_pickup_datetime', 'tpep_dropoff_datetime']] = taxis[['tpep_pickup_datetime', 'tpep_dropoff_datetime']].apply(pd.to_datetime)
taxis['5hrs'] = taxis['tpep_pickup_datetime']-taxis['tpep_dropoff_datetime']
taxis['5hrs'] = taxis['5hrs'].Timedelta(hours)
duration_5hrs
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11696\2778136078.py in ?()
#       1 taxis[['tpep_pickup_datetime', 'tpep_dropoff_datetime']] = taxis[['tpep_pickup_datetime', 'tpep_dropoff_datetime']].apply(pd.to_datetime)
#       2 taxis['5hrs'] = taxis['tpep_pickup_datetime']-taxis['tpep_dropoff_datetime']
# ----> 3 taxis['5hrs'] = taxis['5hrs'].Timedelta(hours)
#       4 duration_5hrs
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'Timedelta'

# %%
taxis
# Out:
#       vendorid tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0            2  2019-10-23 16:39:42   2019-10-23 17:14:10                1
# 1            1  2019-10-23 16:32:08   2019-10-23 16:45:26                1
# 2            2  2019-10-23 16:08:44   2019-10-23 16:21:11                1
# 3            2  2019-10-23 16:22:44   2019-10-23 16:43:26                1
# 4            2  2019-10-23 16:45:11   2019-10-23 16:58:49                1
# ...        ...                  ...                   ...              ...
# 9995         1  2019-10-23 17:39:59   2019-10-23 17:49:26                2
# 9996         1  2019-10-23 17:53:02   2019-10-23 18:00:45                1
# 9997         1  2019-10-23 17:07:16   2019-10-23 17:11:35                1
# 9998         1  2019-10-23 17:38:26   2019-10-23 17:49:28                2
# 9999         1  2019-10-23 17:22:14   2019-10-23 17:52:09                1
#
#       trip_distance  ratecodeid store_and_fwd_flag  pulocationid  \
# ...
