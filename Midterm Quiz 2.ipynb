# %%
import pandas as pd
rt = pd.read_csv('RT_IOT2022.csv')
rt
# Out:
#           no  id.orig_p  id.resp_p proto service  flow_duration  fwd_pkts_tot  \
# 0          0      38667       1883   tcp    mqtt      32.011598             9
# 1          1      51143       1883   tcp    mqtt      31.883584             9
# 2          2      44761       1883   tcp    mqtt      32.124053             9
# 3          3      60893       1883   tcp    mqtt      31.961063             9
# 4          4      51087       1883   tcp    mqtt      31.902362             9
# ...      ...        ...        ...   ...     ...            ...           ...
# 123112  2005      59247      63331   tcp       -       0.000006             1
# 123113  2006      59247      64623   tcp       -       0.000007             1
# 123114  2007      59247      64680   tcp       -       0.000006             1
# 123115  2008      59247      65000   tcp       -       0.000006             1
# 123116  2009      59247      65129   tcp       -       0.000006             1
#
# ...

# %%
c = rt.columns
r = rt.isnull()
is_There_null = [r[f'{x}'].unique()[0] for x in c]
print(is_There_null)
# Out:
# [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]

# %%
attcker1 = rt[rt['Attack_type'] == 'DOS_SYN_Hping']
attcker2= rt[rt['Attack_type'] == 'ARP_poisioning']
attcker3 = rt[rt['Attack_type'] == 'NMAP_UDP_SCAN']
attcker4 = rt[rt['Attack_type'] == 'NMAP_XMAS_TREE_SCAN']
attcker5 = rt[rt['Attack_type'] == 'NMAP_OS_DETECTION']
attcker6 = rt[rt['Attack_type'] == 'NMAP_TCP_scan']
attcker7 = rt[rt['Attack_type'] == 'DDOS_Slowloris']
attcker8 = rt[rt['Attack_type'] == 'NMAP_UDP_SCAN']
attcker9 = rt[rt['Attack_type'] == 'Metasploit_Brute_Force_SSH']
attcker0 = rt[rt['Attack_type'] == 'NMAP_FIN_SCAN']

# %%
attcker0
# Out:
#         no  id.orig_p  id.resp_p proto service  flow_duration  fwd_pkts_tot  \
# 115487   0      54610         80   tcp    http       0.575884             6
# 115488   1      50877         53   udp     dns       0.042745             2
# 115489   2      57535         53   udp     dns       0.001298             1
# 115490   3      33781         53   udp     dns       0.041273             1
# 115491   4      47630         22   tcp       -       0.000000             1
# 115492   5      47631         22   tcp       -       0.000000             1
# 115493   6      65012         22   tcp       -       0.000000             1
# 115494   7      65013         22   tcp       -       0.000000             1
# 115495   8      53043         22   tcp       -       0.000000             1
# 115496   9      53044         22   tcp       -       0.000000             1
# 115497  10      65035         22   tcp       -       0.000000             1
# ...
